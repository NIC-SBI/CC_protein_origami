# %%
tet_name = "sqr-4SG"
entire_sequence = ""\
.replace(" ", "")
segments = """
EIQQLEE EISQLEQ KNSQLKE KNQQLKY G 		P3mS
SGSG
EIQSLEE KNSQLKQ EISQLEE KNQQLKY G 		P7mS
SGSG
ENQQLEQ KNSQLKQ EISQLEQ EISQLEY G		P9mS
SGSG
ENSQLEE KISQLKQ KNSQLKE EIQQLEY G 		P5mS
SGSG
KISQLKQ KIQQLKQ ENQQLEE ENSQLEY G 		P4mS
SGSG
KISQLKE ENQQLEQ KIQQLKE ENSQLEY G 		P8mS
SGSG
KNSQLKE ENSQLEE KIQQLKE KIQQLKY G 		P10mS    
SGSG
KNSQLKE EIQQLEE ENQQLEE KISQLKY G 		P6mS
"""

pairs = [["P3mS","P4mS"], ["P5mS","P6mS"],["P7mS","P8mS"], ["P9mS", "P10mS"]]

pair_types = ["P","P","P","P"]
segments = segments.split('\n')

#ignore the linkers
segments = filter(lambda s: len(s)>10, segments) 
# split into seq name pairs
for n, seg in enumerate(segments):
    spl = seg.split('\t')
    seq = spl[0].replace(" ","")
    name = spl[-1].strip()

    seq = seq.replace(" ","")
    #print seq
    #print name
    
    #has a segment allready been found?
    pos_in_seq=0
    for n1 in range(n-1):
        if segments[n1]['name']==name:
            pos_in_seq=segments[n1]['start']+segments[n1]['len']
            
    
    start = entire_sequence.find(seq,pos_in_seq)
    print start
    
    #find the pair name
    for np, p in enumerate(pairs):
        #do we have the rigth pair
        if name in p:
            #take the remaining pair
            pair_name = p[:]
            pair_name.remove(name)                        
            pair_name=pair_name[0]
            pair_type=pair_types[np]
            #print pair_name

    
    
    segments[n]={"id":n+1, "name": name, 
                 "sequence" :seq, 
                 "start" : start+1,
                 "len" : len(seq),
                 "end" : start+len(seq),
                 "pair_id" : -1,
                 "pair_name": pair_name,
                 "pair_type": pair_type,
                 "pdb_template" : "",
                 "pdb_chain" : ""
                }
   
#find tha pair IDs
for n in range(len(segments)):
    for n1 in range(n+1,len(segments)):
        if segments[n]['name']==segments[n1]['pair_name']:
            segments[n]['pair_id']=segments[n1]['id']      
            segments[n1]['pair_id']=segments[n]['id']
    

segments
# Out:
# 0
# 33
# 66
# 99
# 132
# 165
# 198
# 231
# [{'end': 29,
#   'id': 1,
#   'len': 29,
#   'name': 'P3mS',
#   'pair_id': 5,
#   'pair_name': 'P4mS',
#   'pair_type': 'P',
#   'pdb_chain': '',
#   'pdb_template': '',
#   'sequence': 'EIQQLEEEISQLEQKNSQLKEKNQQLKYG',
#   'start': 1},
#  {'end': 62,
#   'id': 2,
#   'len': 29,
#   'name': 'P7mS',
#   'pair_id': 6,
#   'pair_name': 'P8mS',
#   'pair_type': 'P',
#   'pdb_chain': '',
#   'pdb_template': '',
#   'sequence': 'EIQSLEEKNSQLKQEISQLEEKNQQLKYG',
#   'start': 34},
#  {'end': 95,
#   'id': 3,
#   'len': 29,
#   'name': 'P9mS',
#   'pair_id': 7,
#   'pair_name': 'P10mS',
#   'pair_type': 'P',
#   'pdb_chain': '',
#   'pdb_template': '',
#   'sequence': 'ENQQLEQKNSQLKQEISQLEQEISQLEYG',
#   'start': 67},
#  {'end': 128,
#   'id': 4,
#   'len': 29,
#   'name': 'P5mS',
#   'pair_id': 8,
#   'pair_name': 'P6mS',
#   'pair_type': 'P',
#   'pdb_chain': '',
#   'pdb_template': '',
#   'sequence': 'ENSQLEEKISQLKQKNSQLKEEIQQLEYG',
#   'start': 100},
#  {'end': 161,
#   'id': 5,
#   'len': 29,
#   'name': 'P4mS',
#   'pair_id': 1,
#   'pair_name': 'P3mS',
#   'pair_type': 'P',
#   'pdb_chain': '',
#   'pdb_template': '',
#   'sequence': 'KISQLKQKIQQLKQENQQLEEENSQLEYG',
#   'start': 133},
#  {'end': 194,
#   'id': 6,
#   'len': 29,
#   'name': 'P8mS',
#   'pair_id': 2,
#   'pair_name': 'P7mS',
#   'pair_type': 'P',
#   'pdb_chain': '',
#   'pdb_template': '',
#   'sequence': 'KISQLKEENQQLEQKIQQLKEENSQLEYG',
#   'start': 166},
#  {'end': 227,
#   'id': 7,
#   'len': 29,
#   'name': 'P10mS',
#   'pair_id': 3,
#   'pair_name': 'P9mS',
#   'pair_type': 'P',
#   'pdb_chain': '',
#   'pdb_template': '',
#   'sequence': 'KNSQLKEENSQLEEKIQQLKEKIQQLKYG',
#   'start': 199},
#  {'end': 260,
#   'id': 8,
#   'len': 29,
#   'name': 'P6mS',
#   'pair_id': 4,
#   'pair_name': 'P5mS',
#   'pair_type': 'P',
#   'pdb_chain': '',
#   'pdb_template': '',
#   'sequence': 'KNSQLKEEIQQLEEENQQLEEKISQLKYG',
#   'start': 232}]

# %%
import json            
outname = tet_name+".json"
with open(outname, 'w') as outfile:
    json.dump({"name":tet_name,"entire_sequence": entire_sequence, "pairs":pairs, "pair_types":pair_types, "segments":segments}, outfile, indent=True, sort_keys=True)
# !cat $outname   
cp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b13b731837a3> in <module>()
#       1 import json
# ----> 2 outname = tet_name+".json"
#       3 with open(outname, 'w') as outfile:
#       4     json.dump({"name":tet_name,"entire_sequence": entire_sequence, "pairs":pairs, "pair_types":pair_types, "segments":segments}, outfile, indent=True, sort_keys=True)
#       5 get_ipython().system(u'cat $outname   ')
#
# NameError: name 'tet_name' is not defined

# %%
import json
